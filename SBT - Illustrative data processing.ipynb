# %% [markdown]
# # Science Based Targets - illustrative data processing

# %% [markdown]
# Looking at the spreadsheet it would seem that the `Target` column contains a mix of info relating to near-term, long-term and net-zero targets. Assuming the idea is to split out the info into separate rows (i.e., for each company there should be a separate row for each of near-term, long-term and net-zero with the corresponding target text in that row), here is a rough example of how something might be done.
#
# The basic approach is to separate out the sentences in the `Target` field and then search for target year values in each sentence. The output is then a table showing matches of sentences to target types. This can then be checked and corrected manually in Excel before producing the final table with target sentences married up to target type.

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ## Load data

# %%
raw_data = pd.read_excel( 'data/companies-taking-action.xlsx', sheet_name = 'Worksheet' )

# %%
raw_data
# Out:
#                                            Company Name          ISIN  \
# 0     (ACIP) Alexandria Company for Industrial Packages           NaN
# 1                                              2degrees           NaN
# 2                                         3B-Fibreglass           NaN
# 3                                                 4most           NaN
# 4                                          A&L Goodbody           NaN
# ...                                                 ...           ...
# 4055                          ZTO Express (Cayman) Inc.  US98980A1051
# 4056                                     Zuellig Pharma           NaN
# 4057                                       Zühlke Group           NaN
# 4058                         Zurich Insurance Group Ltd  CH0011075394
# 4059                                             Ørsted  DK0060094928
#
#                        LEI Near term - Target Status  \
# 0                      NaN               Targets Set
# 1     72450039D2LOPG0Z2I07                 Committed
# 2     529900UNERQOV61CA912                 Committed
# 3                      NaN               Targets Set
# 4                      NaN                 Committed
# ...                    ...                       ...
# 4055  549300SCJPK3YZJTJR78                 Committed
# 4056                   NaN                 Committed
# 4057                   NaN                 Committed
# 4058  529900QVNRBND50TXP03                 Committed
# 4059  W9NG6WMZIYEU8VEDOG48               Targets Set
#
#      Near term - Target Classification Near term - Target Year  \
# 0                       Well-below 2°C                    2030
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                       Well-below 2°C                    2030
# 4                                  NaN                     NaN
# ...                                ...                     ...
# 4055                               NaN                     NaN
# 4056                               NaN                     NaN
# 4057                               NaN                     NaN
# 4058                               NaN                     NaN
# 4059                             1.5°C                    2025
#
#      Long term - Target Status Long term - Target Classification  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ...                        ...                               ...
# 4055                       NaN                               NaN
# 4056                       NaN                               NaN
# 4057                       NaN                               NaN
# 4058                       NaN                               NaN
# 4059               Targets Set                             1.5°C
#
#      Long term - Target Year Net-Zero Committed  ...  \
# 0                        NaN                 No  ...
# 1                        NaN                 No  ...
# 2                        NaN                Yes  ...
# 3                        NaN                 No  ...
# 4                        NaN                 No  ...
# ...                      ...                ...  ...
# 4055                     NaN                 No  ...
# 4056                     NaN                 No  ...
# 4057                     NaN                Yes  ...
# 4058                     NaN                 No  ...
# 4059                    2040                Yes  ...
#
#                Organization Type BA1.5  BA1.5 Date             Location  \
# 0     Small or Medium Enterprise    No         NaN                Egypt
# 1                        Company    No         NaN          New Zealand
# 2                        Company   Yes  01/09/2021              Belgium
# 3     Small or Medium Enterprise    No         NaN  United Kingdom (UK)
# 4                        Company    No         NaN              Ireland
# ...                          ...   ...         ...                  ...
# 4055                     Company    No         NaN                China
# 4056                     Company    No         NaN            Singapore
# 4057                     Company   Yes  01/03/2022          Switzerland
# 4058       Financial Institution   Yes  01/06/2019          Switzerland
# 4059                     Company   Yes  01/09/2019              Denmark
#
#        Region                                             Sector        Date  \
# 0      Africa                           Containers and Packaging  01/02/2022
# 1     Oceania                         Telecommunication Services  01/09/2021
# 2      Europe  Consumer Durables, Household and Personal Prod...  01/10/2021
# 3      Europe                              Professional Services  01/09/2022
# 4      Europe                              Professional Services  01/10/2021
# ...       ...                                                ...         ...
# 4055     Asia           Air Freight Transportation and Logistics  01/01/2021
# 4056     Asia  Healthcare Providers and Services, and Healthc...  01/01/2021
# 4057   Europe                              Software and Services  01/03/2022
# 4058   Europe               Banks, Diverse Financials, Insurance  01/07/2019
# 4059   Europe  Electric Utilities and Independent Power Produ...  01/08/2019
#
#                                                  Target  \
# 0     This target was approved using a streamlined t...
# 1                                                   NaN
# 2                                                   NaN
# 3     This target was approved using a streamlined t...
# 4                                                   NaN
# ...                                                 ...
# 4055                                                NaN
# 4056                                                NaN
# 4057                                                NaN
# 4058                                                NaN
# 4059  Ørsted commits to reach net-zero greenhouse ga...
#
#                                   Target Classification  \
# 0     The targets covering greenhouse gas emissions ...
# 1                                                   NaN
# 2                                                   NaN
# 3     The targets covering greenhouse gas emissions ...
# 4                                                   NaN
# ...                                                 ...
# 4055                                                NaN
# 4056                                                NaN
# 4057                                                NaN
# 4058                                                NaN
# 4059  The targets covering greenhouse gas emissions ...
#
#                                               Extension
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4055                                                NaN
# 4056                                                NaN
# 4057                                                NaN
# 4058  Financial Institution. Deadline to submit targ...
# 4059                                                NaN
#
# [4060 rows x 21 columns]

# %% [markdown]
# ## Select unique identifier

# %% [markdown]
# Check that there are no duplicate companies. That way we know we can use company name as a unique identifier.

# %%
raw_data['Company Name'].duplicated().any()
# Out:
# False

# %% [markdown]
# ## Create search terms from year data

# %% [markdown]
# Here we are taking of the year columns ('Near term - Target Year', 'Long term - Target Year', 'Net-Zero Year') and for each company extracting the years we want to search for in the `Target` column text.

# %%
target_year_columns = ['Near term - Target Year', 'Long term - Target Year', 'Net-Zero Year']

# %%
years =  pd.melt(raw_data, id_vars = ['Company Name'], value_vars = target_year_columns).sort_values(by = 'Company Name')

# %%
years
# Out:
#                                             Company Name  \
# 0      (ACIP) Alexandria Company for Industrial Packages
# 4060   (ACIP) Alexandria Company for Industrial Packages
# 8120   (ACIP) Alexandria Company for Industrial Packages
# 1                                               2degrees
# 4061                                            2degrees
# ...                                                  ...
# 8119                                              Ørsted
# 12179                                             Ørsted
# 4027   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
# 12147  Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
# 8087   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
#
#                       variable value
# 0      Near term - Target Year  2030
# 4060   Long term - Target Year   NaN
# 8120             Net-Zero Year   NaN
# 1      Near term - Target Year   NaN
# 4061   Long term - Target Year   NaN
# ...                        ...   ...
# 8119   Long term - Target Year  2040
# 12179            Net-Zero Year  2040
# 4027   Near term - Target Year  2026
# 12147            Net-Zero Year   NaN
# 8087   Long term - Target Year   NaN
#
# [12180 rows x 3 columns]

# %% [markdown]
# We should have a look at non-numeric values as these will need to be cleaned.

# %%
# Get unique non-NaN values.
unique_values = years['value'].dropna().unique()
    
# Select only non-numeric values.
non_numeric_values = filter(lambda value : not str(value).isnumeric(), unique_values)
print(list(non_numeric_values))
# Out:
# ['FY2050', 'FY2030', '2030, 2024, 2030', '2030, 2034', 'FY2040', '2025, 2024', '2031, 2026', '2030, 2024', '2025, 2030', '2030, 2021', '2030, 2025', 'FY2031', 'FY2026', 'FY2045', 'FY2030/2031', '2032, 2025', '2030, 2035', '2024, 2025', '2028, 2025', 'FY2023, FY2030', '2025, 2023', '2022, 2030', '2030, 2022', '2030, 2020', 'FY2034', '2027, 2025', '2025, 2022', '2035, 2025', '2022, 2027', '2026, 2030', '2034, 2024', 'FY2035', '2023, 2030', '2030, 2029', '2025, 2035', 'FY2025', '2030, 2023', '2030, 2026', 'F2030', '2030, 2020, 2025', 'FY2030/31', 'Y2026', '2025, 2029', '2023, 2024', '2031, 2034', '2029, 2025', '2026, 2025', '2032, 2030, 2025', '2026, 2029', 'FY2028', '2030, 2024, 2034', '2033, 2026', '2031, 2025', '2031, 2030', '2025, 2032', '2035/2030', '2030, 2023, 2025', '2031, 2021, 2025']

# %% [markdown]
# It looks like we just have to handle the cases when:
# - We have an FY (to indicate financial year presumably)
# - We have a list of years separated by commas.
# - We have years separated by a / (typically to indicate a financial year)
#
# We can convert these into search terms.

# %%
def convert_year_field_to_search_terms(year_data):
    
    if pd.isnull(year_data):
        return np.NAN
    
    # Strip any spaces.
    year_data = str(year_data).replace(' ', '')
    
    # Split into separate terms when there is more than one.
    if ',' in year_data:
        terms = year_data.split(',')
    elif '/' in year_data:
        terms = year_data.split('/')
    else:
        terms = [year_data]
    
    # Add in the search term without the FY in case the FY is not included in the Target text.
    for term in terms:
        if 'FY' in term:
            terms.append(term.replace('FY', ''))
    
    return terms

# %% [markdown]
# Let's test a couple of test cases.

# %%
print(convert_year_field_to_search_terms('FY2031, 2026'))
print(convert_year_field_to_search_terms('FY2030/31'))
# Out:
# ['FY2031', '2026', '2031']
# ['FY2030', '31', '2030']

# %% [markdown]
# That seems to work OK. Let's now add in our search terms to the original data table (at the right-hand end).

# %%
for col in target_year_columns:
    raw_data[f"{col} search terms"] = raw_data[col].apply(convert_year_field_to_search_terms)

# %%
raw_data
# Out:
#                                            Company Name          ISIN  \
# 0     (ACIP) Alexandria Company for Industrial Packages           NaN
# 1                                              2degrees           NaN
# 2                                         3B-Fibreglass           NaN
# 3                                                 4most           NaN
# 4                                          A&L Goodbody           NaN
# ...                                                 ...           ...
# 4055                          ZTO Express (Cayman) Inc.  US98980A1051
# 4056                                     Zuellig Pharma           NaN
# 4057                                       Zühlke Group           NaN
# 4058                         Zurich Insurance Group Ltd  CH0011075394
# 4059                                             Ørsted  DK0060094928
#
#                        LEI Near term - Target Status  \
# 0                      NaN               Targets Set
# 1     72450039D2LOPG0Z2I07                 Committed
# 2     529900UNERQOV61CA912                 Committed
# 3                      NaN               Targets Set
# 4                      NaN                 Committed
# ...                    ...                       ...
# 4055  549300SCJPK3YZJTJR78                 Committed
# 4056                   NaN                 Committed
# 4057                   NaN                 Committed
# 4058  529900QVNRBND50TXP03                 Committed
# 4059  W9NG6WMZIYEU8VEDOG48               Targets Set
#
#      Near term - Target Classification Near term - Target Year  \
# 0                       Well-below 2°C                    2030
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                       Well-below 2°C                    2030
# 4                                  NaN                     NaN
# ...                                ...                     ...
# 4055                               NaN                     NaN
# 4056                               NaN                     NaN
# 4057                               NaN                     NaN
# 4058                               NaN                     NaN
# 4059                             1.5°C                    2025
#
#      Long term - Target Status Long term - Target Classification  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ...                        ...                               ...
# 4055                       NaN                               NaN
# 4056                       NaN                               NaN
# 4057                       NaN                               NaN
# 4058                       NaN                               NaN
# 4059               Targets Set                             1.5°C
#
#      Long term - Target Year Net-Zero Committed  ...             Location  \
# 0                        NaN                 No  ...                Egypt
# 1                        NaN                 No  ...          New Zealand
# 2                        NaN                Yes  ...              Belgium
# 3                        NaN                 No  ...  United Kingdom (UK)
# 4                        NaN                 No  ...              Ireland
# ...                      ...                ...  ...                  ...
# 4055                     NaN                 No  ...                China
# 4056                     NaN                 No  ...            Singapore
# 4057                     NaN                Yes  ...          Switzerland
# 4058                     NaN                 No  ...          Switzerland
# 4059                    2040                Yes  ...              Denmark
#
#        Region                                             Sector        Date  \
# 0      Africa                           Containers and Packaging  01/02/2022
# 1     Oceania                         Telecommunication Services  01/09/2021
# 2      Europe  Consumer Durables, Household and Personal Prod...  01/10/2021
# 3      Europe                              Professional Services  01/09/2022
# 4      Europe                              Professional Services  01/10/2021
# ...       ...                                                ...         ...
# 4055     Asia           Air Freight Transportation and Logistics  01/01/2021
# 4056     Asia  Healthcare Providers and Services, and Healthc...  01/01/2021
# 4057   Europe                              Software and Services  01/03/2022
# 4058   Europe               Banks, Diverse Financials, Insurance  01/07/2019
# 4059   Europe  Electric Utilities and Independent Power Produ...  01/08/2019
#
#                                                  Target  \
# 0     This target was approved using a streamlined t...
# 1                                                   NaN
# 2                                                   NaN
# 3     This target was approved using a streamlined t...
# 4                                                   NaN
# ...                                                 ...
# 4055                                                NaN
# 4056                                                NaN
# 4057                                                NaN
# 4058                                                NaN
# 4059  Ørsted commits to reach net-zero greenhouse ga...
#
#                                   Target Classification  \
# 0     The targets covering greenhouse gas emissions ...
# 1                                                   NaN
# 2                                                   NaN
# 3     The targets covering greenhouse gas emissions ...
# 4                                                   NaN
# ...                                                 ...
# 4055                                                NaN
# 4056                                                NaN
# 4057                                                NaN
# 4058                                                NaN
# 4059  The targets covering greenhouse gas emissions ...
#
#                                               Extension  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4055                                                NaN
# 4056                                                NaN
# 4057                                                NaN
# 4058  Financial Institution. Deadline to submit targ...
# 4059                                                NaN
#
#      Near term - Target Year search terms  \
# 0                                  [2030]
# 1                                     NaN
# 2                                     NaN
# 3                                  [2030]
# 4                                     NaN
# ...                                   ...
# 4055                                  NaN
# 4056                                  NaN
# 4057                                  NaN
# 4058                                  NaN
# 4059                               [2025]
#
#      Long term - Target Year search terms Net-Zero Year search terms
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
# 2                                     NaN                        NaN
# 3                                     NaN                        NaN
# 4                                     NaN                        NaN
# ...                                   ...                        ...
# 4055                                  NaN                        NaN
# 4056                                  NaN                        NaN
# 4057                                  NaN                        NaN
# 4058                                  NaN                        NaN
# 4059                               [2040]                     [2040]
#
# [4060 rows x 24 columns]

# %% [markdown]
# ## Convert Target field to separate sentences

# %% [markdown]
# First we create a function to convert a paragraph to separate sentences.

# %%
def replace_periods(x):
    return x.group(0).replace('.', '|period|')

def extract_sentences(text):
    
    text = str(text)
    
    # Convert line breaks to periods
    text = text.replace('\n', '.')
    
    # Replace .org as this appears a lot.
    text = text.replace('.org', '|period|org')
    
    # Handle initials followed by periods as these are unlikely to be end of sentences.
    text = re.sub('[A-Z]\.', replace_periods, text)
    
    # Strip any spaces after periods.
    text = text.replace('. ', '.')
    
    # Split on periods
    sentences = text.split('.')
    
    # Put back periods for initials.
    sentences = list(map(lambda x : x.replace('|period|', '.'), sentences))
    
    # Remove empty string senctences
    return pd.Series(list(filter(lambda x : x != '', sentences)))

# %% [markdown]
# Test on an example sentence

# %%
test_sentence = raw_data['Target'][7]
print(test_sentence)
# Out:
# Overall Net-Zero Target
# A.G. Barr plc commits to reach net-zero greenhouse gas emissions across the value chain by FY2050 from a FY2020 base year.
# Near-Term Targets
# A.G. Barr commits to reduce absolute scope 1 and 2 GHG emissions 60% by FY2030 from a FY2020 base year. A.G. Barr also commits to reduce absolute scope 3 GHG emissions from purchased goods and services, upstream transport and distribution and downstream transport and distribution 25% within the same timeframe.
# Long-Term Targets
# A.G. Barr plc commits to reduce absolute scope 1 and 2 GHG emissions 90% by FY2035 from  a FY2020 base year. A.G. Barr plc also commits to reduce scope 3 GHG emissions from  purchased goods and services, upstream transport and distribution and downstream transport  and distribution 90% by FY2050 from a FY2020 base year.

# %%
extract_sentences(test_sentence).to_list()
# Out:
# ['Overall Net-Zero Target',
#  'A.G. Barr plc commits to reach net-zero greenhouse gas emissions across the value chain by FY2050 from a FY2020 base year',
#  'Near-Term Targets',
#  'A.G. Barr commits to reduce absolute scope 1 and 2 GHG emissions 60% by FY2030 from a FY2020 base year',
#  'A.G. Barr also commits to reduce absolute scope 3 GHG emissions from purchased goods and services, upstream transport and distribution and downstream transport and distribution 25% within the same timeframe',
#  'Long-Term Targets',
#  'A.G. Barr plc commits to reduce absolute scope 1 and 2 GHG emissions 90% by FY2035 from  a FY2020 base year',
#  'A.G. Barr plc also commits to reduce scope 3 GHG emissions from  purchased goods and services, upstream transport and distribution and downstream transport  and distribution 90% by FY2050 from a FY2020 base year']

# %% [markdown]
# ## Create search table

# %% [markdown]
# Now we can create our search table which should contain for each company:
# - columns for each of our target type search terms
# - a column containing the separate sentences of the `Target` column

# %%
selected_cols = [
    'Company Name',
    'Near term - Target Year search terms',
    'Long term - Target Year search terms',
    'Net-Zero Year search terms',
    'Target'
]

# %%
sentence_table = raw_data[selected_cols].dropna(subset='Target')

# %%
sentence_table
# Out:
#                                            Company Name  \
# 0     (ACIP) Alexandria Company for Industrial Packages
# 3                                                 4most
# 7                                         A.G. Barr plc
# 9                                         A/S Vestfrost
# 10                             A1 Telekom Austria Group
# ...                                                 ...
# 4047                  Zhuhai Pilot Technology Co., Ltd.
# 4049                                      Zimmer Biomet
# 4050                                         Zimmermann
# 4052                                      ZORDAN SRL SB
# 4059                                             Ørsted
#
#      Near term - Target Year search terms  \
# 0                                  [2030]
# 3                                  [2030]
# 7                          [FY2030, 2030]
# 9                                  [2030]
# 10                                 [2030]
# ...                                   ...
# 4047                               [2030]
# 4049                               [2030]
# 4050                                  NaN
# 4052                               [2030]
# 4059                               [2025]
#
#      Long term - Target Year search terms Net-Zero Year search terms  \
# 0                                     NaN                        NaN
# 3                                     NaN                        NaN
# 7                          [FY2050, 2050]             [FY2050, 2050]
# 9                                  [2050]                     [2050]
# 10                                    NaN                        NaN
# ...                                   ...                        ...
# 4047                                  NaN                        NaN
# 4049                                  NaN                        NaN
# 4050                                  NaN                        NaN
# 4052                               [2050]                     [2050]
# 4059                               [2040]                     [2040]
#
#                                                  Target
# 0     This target was approved using a streamlined t...
# 3     This target was approved using a streamlined t...
# 7     Overall Net-Zero Target\nA.G. Barr plc commits...
# 9     This target was approved using a streamlined t...
# 10    A1 Telekom Austria Group commits to reduce abs...
# ...                                                 ...
# 4047  This target was approved using a streamlined t...
# 4049  Zimmer Biomet commits to reduce absolute scope...
# 4050  Zimmermann commits to reduce absolute scope 1 ...
# 4052  This target was approved using a streamlined t...
# 4059  Ørsted commits to reach net-zero greenhouse ga...
#
# [1954 rows x 5 columns]

# %%
split_sentence_table = pd.concat(
    [sentence_table, sentence_table['Target'].apply(extract_sentences)],
    axis = 1
).drop(columns = 'Target')

# %%
id_cols = [
    'Company Name',
    'Near term - Target Year search terms',
    'Long term - Target Year search terms',
    'Net-Zero Year search terms'
]
search_table = (
    pd.melt(split_sentence_table, id_vars = id_cols)
    .sort_values(by = ['Company Name', 'variable'])
    .dropna(subset = 'value')
)
search_table
# Out:
#                                             Company Name  \
# 0      (ACIP) Alexandria Company for Industrial Packages
# 1954   (ACIP) Alexandria Company for Industrial Packages
# 1                                                  4most
# 1955                                               4most
# 2                                          A.G. Barr plc
# ...                                                  ...
# 29309                                             Ørsted
# 31263                                             Ørsted
# 1938   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
# 3892   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
# 5846   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
#
#       Near term - Target Year search terms  \
# 0                                   [2030]
# 1954                                [2030]
# 1                                   [2030]
# 1955                                [2030]
# 2                           [FY2030, 2030]
# ...                                    ...
# 29309                               [2025]
# 31263                               [2025]
# 1938                                [2026]
# 3892                                [2026]
# 5846                                [2026]
#
#       Long term - Target Year search terms Net-Zero Year search terms  \
# 0                                      NaN                        NaN
# 1954                                   NaN                        NaN
# 1                                      NaN                        NaN
# 1955                                   NaN                        NaN
# 2                           [FY2050, 2050]             [FY2050, 2050]
# ...                                    ...                        ...
# 29309                               [2040]                     [2040]
# 31263                               [2040]                     [2040]
# 1938                                   NaN                        NaN
# 3892                                   NaN                        NaN
# 5846                                   NaN                        NaN
#
#       variable                                              value
# 0            0  This target was approved using a streamlined t...
# 1954         1  https://sciencebasedtargets.org/faqs-for-smes/...
# 1            0  This target was approved using a streamlined t...
# 1955         1  https://sciencebasedtargets.org/faqs-for-smes/...
# 2            0                            Overall Net-Zero Target
# ...        ...                                                ...
# 29309       14  *The target boundary includes land-related emi...
# 31263       15                                         feedstocks
# 1938         0  Żabka commits to reduce absolute scope 1 and s...
# 3892         1  Żabka also commits to reduce scope 3 GHG emiss...
# 5846         2  Żabka commits that 75% of its suppliers by spe...
#
# [5902 rows x 6 columns]

# %% [markdown]
# Now that we have a table with search terms and sentences in the right form, we can see where we have matches.

# %%
def match_search_terms(terms, sentence):
    if not isinstance(terms, list):
        return ''
    for term in terms:
        if term in sentence:
            return 'x'
    return ''

# %%
for col in target_year_columns:
    search_table[f"{col} match"] = search_table.apply(
        lambda x : match_search_terms(x[f"{col} search terms"], x['value']),
        axis = 1
    )

# %%
search_table
# Out:
#                                             Company Name  \
# 0      (ACIP) Alexandria Company for Industrial Packages
# 1954   (ACIP) Alexandria Company for Industrial Packages
# 1                                                  4most
# 1955                                               4most
# 2                                          A.G. Barr plc
# ...                                                  ...
# 29309                                             Ørsted
# 31263                                             Ørsted
# 1938   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
# 3892   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
# 5846   Żabka Polska Sp. z o. o. (Zabka Polska Sp. z o...
#
#       Near term - Target Year search terms  \
# 0                                   [2030]
# 1954                                [2030]
# 1                                   [2030]
# 1955                                [2030]
# 2                           [FY2030, 2030]
# ...                                    ...
# 29309                               [2025]
# 31263                               [2025]
# 1938                                [2026]
# 3892                                [2026]
# 5846                                [2026]
#
#       Long term - Target Year search terms Net-Zero Year search terms  \
# 0                                      NaN                        NaN
# 1954                                   NaN                        NaN
# 1                                      NaN                        NaN
# 1955                                   NaN                        NaN
# 2                           [FY2050, 2050]             [FY2050, 2050]
# ...                                    ...                        ...
# 29309                               [2040]                     [2040]
# 31263                               [2040]                     [2040]
# 1938                                   NaN                        NaN
# 3892                                   NaN                        NaN
# 5846                                   NaN                        NaN
#
#       variable                                              value  \
# 0            0  This target was approved using a streamlined t...
# 1954         1  https://sciencebasedtargets.org/faqs-for-smes/...
# 1            0  This target was approved using a streamlined t...
# 1955         1  https://sciencebasedtargets.org/faqs-for-smes/...
# 2            0                            Overall Net-Zero Target
# ...        ...                                                ...
# 29309       14  *The target boundary includes land-related emi...
# 31263       15                                         feedstocks
# 1938         0  Żabka commits to reduce absolute scope 1 and s...
# 3892         1  Żabka also commits to reduce scope 3 GHG emiss...
# 5846         2  Żabka commits that 75% of its suppliers by spe...
#
#       Near term - Target Year match Long term - Target Year match  \
# 0
# 1954                              x
# 1
# 1955                              x
# 2
# ...                             ...                           ...
# 29309
# 31263
# 1938                              x
# 3892
# 5846                              x
#
#       Net-Zero Year match
# 0
# 1954
# 1
# 1955
# 2
# ...                   ...
# 29309
# 31263
# 1938
# 3892
# 5846
#
# [5902 rows x 9 columns]

# %% [markdown]
# We can now export this as csv. In Excel we can then run through by eye and
# tap in extra `x`s where needed. Then there'd be a bit more code to reconstruct the sentences correctly according to the matches.

# %%
search_table.to_csv('data/search-matches.csv', index = False)
